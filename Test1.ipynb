# %%
# !pip install torch torchvision tqdm
# Out:
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# ...

# %%
pip install tensorflow

# %%
# !git clone https://github.com/khalooei/ALOCC-CVPR2018
# Out:
# Cloning into 'ALOCC-CVPR2018'...
# remote: Enumerating objects: 159, done.
# remote: Counting objects: 100% (41/41), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 159 (delta 36), reused 35 (delta 35), pack-reused 118
# Receiving objects: 100% (159/159), 88.33 MiB | 11.66 MiB/s, done.
# Resolving deltas: 100% (73/73), done.
# Updating files: 100% (52/52), done.

# %%
# !git clone https://github.com/nogibjj/Detecting-AI-Generated-Fake-Images.git
# Out:
# Cloning into 'Detecting-AI-Generated-Fake-Images'...
# remote: Enumerating objects: 380, done.
# remote: Counting objects: 100% (111/111), done.
# remote: Compressing objects: 100% (65/65), done.
# remote: Total 380 (delta 49), reused 105 (delta 43), pack-reused 269
# Receiving objects: 100% (380/380), 221.42 MiB | 24.46 MiB/s, done.
# Resolving deltas: 100% (150/150), done.
# Updating files: 100% (97/97), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !gdown https://drive.google.com/uc?id=1AMPtj0DJCgTz55HKGB8CWqd1K7LxXnk6 -O /content/drive/MyDrive/anogan_weights.pth
# Out:
# Failed to retrieve file url:
#
# 	Cannot retrieve the public link of the file. You may need to change
# 	the permission to 'Anyone with the link', or have had many accesses.
# 	Check FAQ in https://github.com/wkentaro/gdown?tab=readme-ov-file#faq.
#
# You may still be able to access the file from the browser:
#
# 	https://drive.google.com/uc?id=1AMPtj0DJCgTz55HKGB8CWqd1K7LxXnk6
#
# but Gdown can't. Please check connections and permissions.
